# %%
import pandas as pd
import numpy as np
import os

# %%
all_months_data = pd.DataFrame()
files = [file for file in os.listdir('../sliders/08 Lesson Sales Analysis/Sales_Data') ]
for file in files:
    df = pd.read_csv("../sliders/08 Lesson Sales Analysis/Sales_Data/"+file)
    all_months_data = pd.concat([all_months_data, df])
all_months_data.head()
# Out:
#   Order ID               Product Quantity Ordered Price Each      Order Date  \
# 0   295665    Macbook Pro Laptop                1       1700  12/30/19 00:01
# 1   295666    LG Washing Machine                1      600.0  12/29/19 07:03
# 2   295667  USB-C Charging Cable                1      11.95  12/12/19 18:21
# 3   295668      27in FHD Monitor                1     149.99  12/22/19 15:13
# 4   295669  USB-C Charging Cable                1      11.95  12/18/19 12:38
#
#                          Purchase Address  Unnamed: 0
# 0  136 Church St, New York City, NY 10001         NaN
# 1     562 2nd St, New York City, NY 10001         NaN
# 2    277 Main St, New York City, NY 10001         NaN
# 3     410 6th St, San Francisco, CA 94016         NaN
# 4           43 Hill St, Atlanta, GA 30301         NaN

# %%
all_months_data.to_csv('../sliders/08 Lesson Sales Analysis/Sales_Data/all_data.csv', index=False)

# %%
all_data = pd.read_csv('../sliders/08 Lesson Sales Analysis/Sales_Data/all_data.csv')
all_data.head()
# Out:
#   Order ID               Product Quantity Ordered Price Each      Order Date  \
# 0   295665    Macbook Pro Laptop                1       1700  12/30/19 00:01
# 1   295666    LG Washing Machine                1      600.0  12/29/19 07:03
# 2   295667  USB-C Charging Cable                1      11.95  12/12/19 18:21
# 3   295668      27in FHD Monitor                1     149.99  12/22/19 15:13
# 4   295669  USB-C Charging Cable                1      11.95  12/18/19 12:38
#
#                          Purchase Address  Unnamed: 0
# 0  136 Church St, New York City, NY 10001         NaN
# 1     562 2nd St, New York City, NY 10001         NaN
# 2    277 Main St, New York City, NY 10001         NaN
# 3     410 6th St, San Francisco, CA 94016         NaN
# 4           43 Hill St, Atlanta, GA 30301         NaN

# %%
non_df = all_data[all_data.isna().any(axis=1)]
non_df.head()
# Out:
#   Order ID               Product Quantity Ordered Price Each      Order Date  \
# 0   295665    Macbook Pro Laptop                1       1700  12/30/19 00:01
# 1   295666    LG Washing Machine                1      600.0  12/29/19 07:03
# 2   295667  USB-C Charging Cable                1      11.95  12/12/19 18:21
# 3   295668      27in FHD Monitor                1     149.99  12/22/19 15:13
# 4   295669  USB-C Charging Cable                1      11.95  12/18/19 12:38
#
#                          Purchase Address  Unnamed: 0
# 0  136 Church St, New York City, NY 10001         NaN
# 1     562 2nd St, New York City, NY 10001         NaN
# 2    277 Main St, New York City, NY 10001         NaN
# 3     410 6th St, San Francisco, CA 94016         NaN
# 4           43 Hill St, Atlanta, GA 30301         NaN

# %%
all_data =  all_data.dropna(how='all')

# %%
all_data.isna()
# Out:
#         Order ID  Product  Quantity Ordered  Price Each  Order Date  \
# 0          False    False             False       False       False
# 1          False    False             False       False       False
# 2          False    False             False       False       False
# 3          False    False             False       False       False
# 4          False    False             False       False       False
# ...          ...      ...               ...         ...         ...
# 186847     False    False             False       False       False
# 186848     False    False             False       False       False
# 186849     False    False             False       False       False
# 186850     False    False             False       False       False
# 186851     False    False             False       False       False
#
#         Purchase Address  Unnamed: 0
# 0                  False        True
# 1                  False        True
# 2                  False        True
# 3                  False        True
# 4                  False        True
# ...                  ...         ...
# 186847             False        True
# 186848             False        True
# 186849             False        True
# 186850             False        True
# 186851             False        True
#
# [186305 rows x 7 columns]

# %%
all_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 186305 entries, 0 to 186851
# Data columns (total 7 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Order ID          186305 non-null  object
#  1   Product           186305 non-null  object
#  2   Quantity Ordered  186305 non-null  object
#  3   Price Each        186305 non-null  object
#  4   Order Date        186305 non-null  object
#  5   Purchase Address  186305 non-null  object
#  6   Unnamed: 0        0 non-null       float64
# dtypes: float64(1), object(6)
# memory usage: 11.4+ MB

# %%
temp = all_data[all_data['Order Date'].str[0:2]=='OR']
temp
# Out:
# Empty DataFrame
# Columns: [Order ID, Product, Quantity Ordered, Price Each, Order Date, Purchase Address, Unnamed: 0]
# Index: []

# %%
all_data['Quantity Ordered'] = pd.to_numeric(all_data['Quantity Ordered'], errors='coerce')
all_data['Price Each'] = pd.to_numeric(all_data['Price Each'], errors='coerce')
# Out:
# <ipython-input-28-6dd5889dd425>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_data['Quantity Ordered'] = pd.to_numeric(all_data['Quantity Ordered'], errors='coerce')
# <ipython-input-28-6dd5889dd425>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_data['Price Each'] = pd.to_numeric(all_data['Price Each'], errors='coerce')

# %%
all_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 186305 entries, 0 to 186851
# Data columns (total 7 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Order ID          186305 non-null  object
#  1   Product           186305 non-null  object
#  2   Quantity Ordered  185950 non-null  float64
#  3   Price Each        185950 non-null  float64
#  4   Order Date        186305 non-null  object
#  5   Purchase Address  186305 non-null  object
#  6   Unnamed: 0        0 non-null       float64
# dtypes: float64(3), object(4)
# memory usage: 11.4+ MB

# %%
all_data['Month'] = all_data['Order Date'].str[0:2]
# Out:
# <ipython-input-30-d69b0e923aac>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_data['Month'] = all_data['Order Date'].str[0:2]

# %%
all_data.head()
# Out:
#   Order ID               Product  Quantity Ordered  Price Each  \
# 0   295665    Macbook Pro Laptop               1.0     1700.00
# 1   295666    LG Washing Machine               1.0      600.00
# 2   295667  USB-C Charging Cable               1.0       11.95
# 3   295668      27in FHD Monitor               1.0      149.99
# 4   295669  USB-C Charging Cable               1.0       11.95
#
#        Order Date                        Purchase Address  Unnamed: 0 Month
# 0  12/30/19 00:01  136 Church St, New York City, NY 10001         NaN    12
# 1  12/29/19 07:03     562 2nd St, New York City, NY 10001         NaN    12
# 2  12/12/19 18:21    277 Main St, New York City, NY 10001         NaN    12
# 3  12/22/19 15:13     410 6th St, San Francisco, CA 94016         NaN    12
# 4  12/18/19 12:38           43 Hill St, Atlanta, GA 30301         NaN    12

# %%
all_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 186305 entries, 0 to 186851
# Data columns (total 8 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Order ID          186305 non-null  object
#  1   Product           186305 non-null  object
#  2   Quantity Ordered  185950 non-null  float64
#  3   Price Each        185950 non-null  float64
#  4   Order Date        186305 non-null  object
#  5   Purchase Address  186305 non-null  object
#  6   Unnamed: 0        0 non-null       float64
#  7   Month             186305 non-null  object
# dtypes: float64(3), object(5)
# memory usage: 12.8+ MB

# %%
all_data['Month'] = all_data['Month'].astype('Int32')

# %%
all_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 186305 entries, 0 to 186851
# Data columns (total 8 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Order ID          186305 non-null  object
#  1   Product           186305 non-null  object
#  2   Quantity Ordered  185950 non-null  float64
#  3   Price Each        185950 non-null  float64
#  4   Order Date        186305 non-null  object
#  5   Purchase Address  186305 non-null  object
#  6   Unnamed: 0        0 non-null       float64
#  7   Month             185950 non-null  Int32
# dtypes: Int32(1), float64(3), object(4)
# memory usage: 12.3+ MB

# %%
all_data['Sales'] = all_data['Quantity Ordered'] * all_data['Price Each']
all_data.head()
# Out:
#   Order ID               Product  Quantity Ordered  Price Each  \
# 0   295665    Macbook Pro Laptop               1.0     1700.00
# 1   295666    LG Washing Machine               1.0      600.00
# 2   295667  USB-C Charging Cable               1.0       11.95
# 3   295668      27in FHD Monitor               1.0      149.99
# 4   295669  USB-C Charging Cable               1.0       11.95
#
#        Order Date                        Purchase Address  Unnamed: 0  Month  \
# 0  12/30/19 00:01  136 Church St, New York City, NY 10001         NaN     12
# 1  12/29/19 07:03     562 2nd St, New York City, NY 10001         NaN     12
# 2  12/12/19 18:21    277 Main St, New York City, NY 10001         NaN     12
# 3  12/22/19 15:13     410 6th St, San Francisco, CA 94016         NaN     12
# 4  12/18/19 12:38           43 Hill St, Atlanta, GA 30301         NaN     12
#
#      Sales
# 0  1700.00
# 1   600.00
# 2    11.95
# 3   149.99
# 4    11.95

# %%
all_data['Sales'].sum()
# Out:
# 34492035.96999999

# %%
month = all_data['Month']
month.value_counts()
# Out:
# 12    24984
# 10    20282
# 4     18279
# 11    17573
# 5     16566
# 3     15153
# 7     14293
# 6     13554
# 2     11975
# 8     11961
# 9     11621
# 1      9709
# Name: Month, dtype: Int64

# %%
best_month_for_sales = all_data.groupby('Month').sum()
best_month_for_sales
# Out:
#        Quantity Ordered    Price Each  Unnamed: 0         Sales
# Month
# 1               10903.0  1.811768e+06         0.0  1.822257e+06
# 2               13449.0  2.188885e+06         0.0  2.202022e+06
# 3               17005.0  2.791208e+06         0.0  2.807100e+06
# 4               20558.0  3.367671e+06         0.0  3.390670e+06
# 5               18667.0  3.135125e+06         0.0  3.152607e+06
# 6               15253.0  2.562026e+06         0.0  2.577802e+06
# 7               16072.0  2.632540e+06         0.0  2.647776e+06
# 8               13448.0  2.230345e+06         0.0  2.244468e+06
# 9               13109.0  2.084992e+06         0.0  2.097560e+06
# 10              22703.0  3.715555e+06         0.0  3.736727e+06
# 11              19798.0  3.180601e+06         0.0  3.199603e+06
# 12              28114.0  4.588415e+06         0.0  4.613443e+06

# %%
import matplotlib.pyplot as plt
import seaborn as sns
months = range(1,13)
plt.bar(months, best_month_for_sales['Sales'])
plt.xticks(months)
plt.ylabel('sales in usd')
plt.xlabel('Month number')
plt.show()

# %%
all_data.head()
# Out:
#   Order ID               Product  Quantity Ordered  Price Each  \
# 0   295665    Macbook Pro Laptop               1.0     1700.00
# 1   295666    LG Washing Machine               1.0      600.00
# 2   295667  USB-C Charging Cable               1.0       11.95
# 3   295668      27in FHD Monitor               1.0      149.99
# 4   295669  USB-C Charging Cable               1.0       11.95
#
#        Order Date                        Purchase Address  Unnamed: 0  Month  \
# 0  12/30/19 00:01  136 Church St, New York City, NY 10001         NaN     12
# 1  12/29/19 07:03     562 2nd St, New York City, NY 10001         NaN     12
# 2  12/12/19 18:21    277 Main St, New York City, NY 10001         NaN     12
# 3  12/22/19 15:13     410 6th St, San Francisco, CA 94016         NaN     12
# 4  12/18/19 12:38           43 Hill St, Atlanta, GA 30301         NaN     12
#
#      Sales
# 0  1700.00
# 1   600.00
# 2    11.95
# 3   149.99
# 4    11.95

# %% [markdown]
# # What city could be the most product

# %%
all_data.groupby(['Purchase Address']).sum()
# Out:
#                                         Quantity Ordered  Price Each  \
# Purchase Address
# 1 11th St, Atlanta, GA 30301                         1.0       11.95
# 1 11th St, Los Angeles, CA 90001                     1.0     1700.00
# 1 11th St, San Francisco, CA 94016                   1.0      700.00
# 1 12th St, Los Angeles, CA 90001                     1.0      150.00
# 1 12th St, New York City, NY 10001                   1.0       11.99
# ...                                                  ...         ...
# 999 Wilson St, Los Angeles, CA 90001                 1.0      999.99
# 999 Wilson St, New York City, NY 10001               1.0      150.00
# 999 Wilson St, Portland, OR 97035                    1.0        2.99
# 999 Wilson St, San Francisco, CA 94016               1.0      150.00
# Purchase Address                                     0.0        0.00
#
#                                         Unnamed: 0  Month    Sales
# Purchase Address
# 1 11th St, Atlanta, GA 30301                   0.0      3    11.95
# 1 11th St, Los Angeles, CA 90001               0.0     10  1700.00
# 1 11th St, San Francisco, CA 94016             0.0      9   700.00
# 1 12th St, Los Angeles, CA 90001               0.0      3   150.00
# 1 12th St, New York City, NY 10001             0.0     10    11.99
# ...                                            ...    ...      ...
# 999 Wilson St, Los Angeles, CA 90001           0.0      9   999.99
# 999 Wilson St, New York City, NY 10001         0.0      2   150.00
# 999 Wilson St, Portland, OR 97035              0.0      5     2.99
# 999 Wilson St, San Francisco, CA 94016         0.0      6   150.00
# Purchase Address                               0.0      0     0.00
#
# [140788 rows x 5 columns]

# %%
def get_city(address):
    return address.split(",")[1].strip(" ")

def get_state(address):
    return address.split(",")[2].split(" ")[1]

for city in all_data['Purchase Address']:
#     print(city)
    all_data['City'] = all_data['Purchase Address'].apply(lambda x: f"{get_city(city)}  ({get_state(city)})")
# all_data['City'] = get_city(all_data[all_data['Purchase Address']])
# all_data['City'] = get_state("1 11th St, Atlanta, GA 30301")
# "1 11th St, Atlanta, GA 30301".split(",")[1].strip(" ")
# all_data['City'] = all_data['Purchase Address'].apply(lambda x: f"{get_city(x)}  ({get_state(x)})")
all_data.head()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-136-35d9cbec6251> in <module>
#       7 for city in all_data['Purchase Address']:
#       8 #     print(city)
# ----> 9     all_data['City'] = all_data['Purchase Address'].apply(lambda x: f"{get_city(city)}  ({get_state(city)})")
#      10 # all_data['City'] = get_city(all_data[all_data['Purchase Address']])
#      11 # all_data['City'] = get_state("1 11th St, Atlanta, GA 30301")
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    4136             else:
#    4137                 values = self.astype(object)._values
# -> 4138                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    4139
#    4140         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-136-35d9cbec6251> in <lambda>(x)
#       7 for city in all_data['Purchase Address']:
#       8 #     print(city)
# ----> 9     all_data['City'] = all_data['Purchase Address'].apply(lambda x: f"{get_city(city)}  ({get_state(city)})")
#      10 # all_data['City'] = get_city(all_data[all_data['Purchase Address']])
#      11 # all_data['City'] = get_state("1 11th St, Atlanta, GA 30301")
#
# <ipython-input-136-35d9cbec6251> in get_city(address)
#       1 def get_city(address):
# ----> 2     return address.split(",")[1].strip(" ")
#       3
#       4 def get_state(address):
#       5     return address.split(",")[2].split(" ")[1]
#
# IndexError: list index out of range

# %%
all_data['Purchase Address']
# Out:
# 0         136 Church St, New York City, NY 10001
# 1            562 2nd St, New York City, NY 10001
# 2           277 Main St, New York City, NY 10001
# 3            410 6th St, San Francisco, CA 94016
# 4                  43 Hill St, Atlanta, GA 30301
#                            ...
# 186847             795 Pine St, Boston, MA 02215
# 186848     495 North St, New York City, NY 10001
# 186849     319 Ridge St, San Francisco, CA 94016
# 186850      916 Main St, San Francisco, CA 94016
# 186851            209 11th St, Atlanta, GA 30301
# Name: Purchase Address, Length: 186305, dtype: object

# %%
# def get_city(address):
#     return address.split(",")[1].strip(" ")

# def get_state(address):
#     return address.split(",")[2].split(" ")
# get_city(all_data['Purchase Address'])

# all_data['City'] = all_data['Purchase Address'].apply(lambda x: f"{get_city(x)}  ({get_state(x)})")
all_data.head()

# %%
all_data.groupby('City').sum()['Sales']

# %%
# for hour in all_data['Order Date']:
#     print(pd.to_datetime(hour, dayfirst=True, errors='coerce'))
all_data['Hour'] = pd.to_datetime(all_data['Order Date'], dayfirst=True).dt.hour
all_data.head()

# %%
all_data.head()
