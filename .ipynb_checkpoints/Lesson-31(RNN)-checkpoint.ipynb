# %%
# standard imports 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# import data 
df=pd.read_csv('data/data.csv',parse_dates=True,index_col='DATE')
df.head(2)
# Out:
#             RSCCASN
# DATE
# 1992-01-01     6938
# 1992-02-01     7524

# %%
# rename the RSCCASN column to sales 
df.columns = ['Sales']
df.head()
# Out:
#             Sales
# DATE
# 1992-01-01   6938
# 1992-02-01   7524
# 1992-03-01   8475
# 1992-04-01   9401
# 1992-05-01   9558

# %%
# plot the data 
df.plot(figsize=(12,8))
# Out:
# <AxesSubplot:xlabel='DATE'>

# %%
# check  the first and last date 

df
# Out:
#             Sales
# DATE
# 1992-01-01   6938
# 1992-02-01   7524
# 1992-03-01   8475
# 1992-04-01   9401
# 1992-05-01   9558
# ...           ...
# 2019-06-01  21123
# 2019-07-01  21714
# 2019-08-01  23791
# 2019-09-01  19695
# 2019-10-01  21113
#
# [334 rows x 1 columns]

# %%
#total dataframe length
len(df)
# Out:
# 334

# %%
#Data is monthly, let's forecast 1.5 years into the future.
len(df)-18
# Out:
# 316

# %%
# test data 
test_size = 18
test_ind = len(df)- test_size

# %%
# training & test data 
train = df.iloc[:test_ind]
test = df.iloc[test_ind:]
train.head()
# Out:
#             Sales
# DATE
# 1992-01-01   6938
# 1992-02-01   7524
# 1992-03-01   8475
# 1992-04-01   9401
# 1992-05-01   9558

# %%
test.head()
# Out:
#             Sales
# DATE
# 2018-05-01  23764
# 2018-06-01  21589
# 2018-07-01  21919
# 2018-08-01  23381
# 2018-09-01  20260

# %%
# scale the data 
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
scaler.fit(train)

scaled_train = scaler.transform(train)
scaled_test = scaler.transform(test)

# %%
from tensorflow.keras.preprocessing.sequence import TimeseriesGenerator
# Let's redefine to get 12 months back and then predict the next month out
length = 12

# create an instance of the class and specify the input and output aspects of your time series problem (input,output,length of traning data )
generator = TimeseriesGenerator(scaled_train, scaled_train, length=length, batch_size=1)

# %%
X, y = generator[0]

# %%
print(f'Given the Array: \n{X.flatten()}')
print(f'Predict this y: \n {y}')
# Out:
# Given the Array:
# [0.         0.02127505 0.05580163 0.08942056 0.09512053 0.08146965
#  0.07860151 0.12979233 0.09566512 0.1203892  0.15426227 0.41595266]
# Predict this y:
#  [[0.02047633]]

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,SimpleRNN

# %%
# We're only using one feature in our time series
n_features = 1
model = Sequential()
model.add(SimpleRNN(100, input_shape=(length, n_features)))

# Final Prediction
model.add(Dense(1))

model.compile(
    optimizer='adam',
    loss='mse'
)
# Out:
# 2022-01-10 01:10:50.366402: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn (SimpleRNN)      (None, 100)               10200
#
#  dense (Dense)               (None, 1)                 101
#
# =================================================================
# Total params: 10,301
# Trainable params: 10,301
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Stop training when a monitored metric has stopped improving
from tensorflow.keras.callbacks import EarlyStopping

early_stop = EarlyStopping(monitor='val_loss',patience=2)
validation_generator = TimeseriesGenerator(scaled_test,scaled_test, length=length, batch_size=1)

# fit model
model.fit_generator(
    generator,epochs=20,
    validation_data=validation_generator,
    callbacks=[early_stop]
)
# Out:
# Epoch 1/20
#  26/304 [=>............................] - ETA: 1s - loss: 0.0058
# /var/folders/jt/3z4p35t93fj67msdhn05ms480000gn/T/ipykernel_1550/1245756587.py:8: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   model.fit_generator(
# 304/304 [==============================] - 1s 5ms/step - loss: 0.0053 - val_loss: 0.0046
# Epoch 2/20
# 304/304 [==============================] - 1s 5ms/step - loss: 0.0034 - val_loss: 0.0078
# Epoch 3/20
# 304/304 [==============================] - 1s 4ms/step - loss: 0.0063 - val_loss: 0.0034
# Epoch 4/20
# 304/304 [==============================] - 1s 4ms/step - loss: 0.0037 - val_loss: 0.0034
# Epoch 5/20
# 304/304 [==============================] - 2s 5ms/step - loss: 0.0042 - val_loss: 0.0072
# Epoch 6/20
# 304/304 [==============================] - 1s 4ms/step - loss: 0.0045 - val_loss: 0.0030
# Epoch 7/20
# 304/304 [==============================] - 1s 4ms/step - loss: 0.0047 - val_loss: 0.0076
# Epoch 8/20
# 304/304 [==============================] - 1s 4ms/step - loss: 0.0074 - val_loss: 0.0012
# Epoch 9/20
# 304/304 [==============================] - 1s 5ms/step - loss: 0.0023 - val_loss: 0.0022
# Epoch 10/20
# 304/304 [==============================] - 2s 5ms/step - loss: 0.0036 - val_loss: 0.0065

# %%
losses = pd.DataFrame(model.history.history)
losses.plot()
# Out:
# <AxesSubplot:>

# %%
test_predictions = []

first_eval_batch = scaled_train[-length:]
first_eval_batch
# Out:
# array([[0.53252977],
#        [0.48591345],
#        [0.49364653],
#        [0.56629393],
#        [0.46405751],
#        [0.48536886],
#        [0.63534708],
#        [0.97233517],
#        [0.32468051],
#        [0.42285071],
#        [0.5615016 ],
#        [0.49658728]])

# %%
current_batch = first_eval_batch.reshape((1, length, n_features))

for i in range(len(test)):
    
    # get prediction 1 time stamp ahead ([0] is for grabbing just the number instead of [array])
    current_pred = model.predict(current_batch)[0]
    
    # store prediction
    test_predictions.append(current_pred) 
    
    # update batch to now include prediction and drop first value
    current_batch = np.append(current_batch[:,1:,:],[[current_pred]],axis=1)
current_batch
# Out:
# array([[[0.50483835],
#         [1.06411648],
#         [0.41462392],
#         [0.45796502],
#         [0.60137361],
#         [0.54521716],
#         [0.62279183],
#         [0.57052439],
#         [0.47486058],
#         [0.5932278 ],
#         [0.81512159],
#         [0.46712932]]])

# %%
true_predictions = scaler.inverse_transform(test_predictions)
true_predictions
# Out:
# array([[22765.40903378],
#        [20912.42617464],
#        [20587.82094002],
#        [24188.88045359],
#        [24301.10722303],
#        [19181.83498216],
#        [20843.26744175],
#        [36248.0242691 ],
#        [18358.40114641],
#        [19552.18841076],
#        [23502.23479319],
#        [21955.46135616],
#        [24092.17807531],
#        [22652.52392244],
#        [20017.55978179],
#        [23277.86662531],
#        [29389.70910501],
#        [19804.6099875 ]])

# %%
# IGNORE WARNINGS
test['Predictions'] = true_predictions
# Out:
# /var/folders/jt/3z4p35t93fj67msdhn05ms480000gn/T/ipykernel_1550/1339453577.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['Predictions'] = true_predictions

# %%
 test.head()
# Out:
#             Sales   Predictions
# DATE
# 2018-05-01  23764  22765.409034
# 2018-06-01  21589  20912.426175
# 2018-07-01  21919  20587.820940
# 2018-08-01  23381  24188.880454
# 2018-09-01  20260  24301.107223

# %%
test.plot(figsize=(12,8))
# Out:
# <AxesSubplot:xlabel='DATE'>

# %%
#model
#from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM

# %%
# We're only using one feature in our time series
n_features = 1

# %%
# define model
model = Sequential()
model.add(LSTM(100, activation='relu', input_shape=(length, n_features)))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mse')

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 100)               40800
#
#  dense_1 (Dense)             (None, 1)                 101
#
# =================================================================
# Total params: 40,901
# Trainable params: 40,901
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow.keras.callbacks import EarlyStopping
early_stop = EarlyStopping(monitor='val_loss',patience=2)

# %%
validation_generator = TimeseriesGenerator(scaled_test,scaled_test, length=length, batch_size=1)

# %%
# fit model
model.fit_generator(generator,epochs=20,
                    validation_data=validation_generator,
                   callbacks=[early_stop])
# Out:
# /var/folders/jt/3z4p35t93fj67msdhn05ms480000gn/T/ipykernel_1550/1350552164.py:2: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   model.fit_generator(generator,epochs=20,
# Epoch 1/20
# 304/304 [==============================] - 4s 7ms/step - loss: 0.0249 - val_loss: 0.0026
# Epoch 2/20
# 304/304 [==============================] - 2s 6ms/step - loss: 0.0178 - val_loss: 0.0022
# Epoch 3/20
# 304/304 [==============================] - 2s 6ms/step - loss: 0.0133 - val_loss: 0.0339
# Epoch 4/20
# 304/304 [==============================] - 2s 6ms/step - loss: 0.0064 - val_loss: 0.0140

# %%
losses = pd.DataFrame(model.history.history)

# %%
losses.plot()
# Out:
# <AxesSubplot:>

# %%
test_predictions = []

first_eval_batch = scaled_train[-length:]
current_batch = first_eval_batch.reshape((1, length, n_features))

for i in range(len(test)):
    
    # get prediction 1 time stamp ahead ([0] is for grabbing just the number instead of [array])
    current_pred = model.predict(current_batch)[0]
    
    # store prediction
    test_predictions.append(current_pred) 
    
    # update batch to now include prediction and drop first value
    current_batch = np.append(current_batch[:,1:,:],[[current_pred]],axis=1)

# %%
true_predictions = scaler.inverse_transform(test_predictions)

# %%
# IGNORE WARNINGS
test['Predictions'] = true_predictions
# Out:
# /var/folders/jt/3z4p35t93fj67msdhn05ms480000gn/T/ipykernel_1550/1339453577.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['Predictions'] = true_predictions

# %%
test
# Out:
#             Sales   Predictions
# DATE
# 2018-05-01  23764  17945.941747
# 2018-06-01  21589  17370.113413
# 2018-07-01  21919  17549.792316
# 2018-08-01  23381  18571.941971
# 2018-09-01  20260  17180.249091
# 2018-10-01  21473  17517.439984
# 2018-11-01  25831  19851.615762
# 2018-12-01  34706  25852.899491
# 2019-01-01  16410  14595.873846
# 2019-02-01  18134  15828.011577
# 2019-03-01  22093  17636.339648
# 2019-04-01  21597  16595.709630
# 2019-05-01  23200  15362.620505
# 2019-06-01  21123  15157.440294
# 2019-07-01  21714  15265.584030
# 2019-08-01  23791  15684.671176
# 2019-09-01  19695  15088.897218
# 2019-10-01  21113  15216.268313

# %%
test.plot(figsize=(12,8))
# Out:
# <AxesSubplot:xlabel='DATE'>

# %%
full_scaler = MinMaxScaler()
scaled_full_data = full_scaler.fit_transform(df)

# %%
length = 12 # Length of the output sequences (in number of timesteps)
generator = TimeseriesGenerator(scaled_full_data, scaled_full_data, length=length, batch_size=1)

# %%
model = Sequential()
model.add(LSTM(100, activation='relu', input_shape=(length, n_features)))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mse')


# fit model
model.fit_generator(generator,epochs=8)
# Out:
# /var/folders/jt/3z4p35t93fj67msdhn05ms480000gn/T/ipykernel_1550/2403673229.py:8: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   model.fit_generator(generator,epochs=8)
# Epoch 1/8
# 322/322 [==============================] - 3s 7ms/step - loss: 0.0250
# Epoch 2/8
# 322/322 [==============================] - 2s 6ms/step - loss: 0.0155
# Epoch 3/8
# 322/322 [==============================] - 2s 7ms/step - loss: 0.0084
# Epoch 4/8
# 322/322 [==============================] - 2s 6ms/step - loss: 0.0047
# Epoch 5/8
# 322/322 [==============================] - 2s 6ms/step - loss: 0.0034
# Epoch 6/8
# 322/322 [==============================] - 2s 6ms/step - loss: 0.0020
# Epoch 7/8
# 322/322 [==============================] - 2s 6ms/step - loss: 0.0018
# Epoch 8/8
# 322/322 [==============================] - 2s 7ms/step - loss: 0.0017
